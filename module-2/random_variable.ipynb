# %% [markdown]
# # Module 2. Variabel Acak dan Distribusi Probabilitas

# %% [markdown]
# ### 1. Import Data
#
# Cari data dari Kaggle dalam bentuk CSV, letakkan dalam satu direktori dengan file IPYNB

# %%
import pandas as pd

# %%
df = pd.read_csv("time-wasters_on_social_media.csv")

# %%
# menampilkan data
df.head()
# Out:
#    UserID  Age  Gender       Location  Income   Debt  Owns Property  \
# 0       1   56    Male       Pakistan   82812   True           True
# 1       2   46  Female         Mexico   27999  False           True
# 2       3   32  Female  United States   42436  False           True
# 3       4   60    Male         Barzil   62963   True          False
# 4       5   25    Male       Pakistan   22096  False           True
#
#       Profession Demographics   Platform  ...  ProductivityLoss  Satisfaction  \
# 0       Engineer        Rural  Instagram  ...                 3             7
# 1         Artist        Urban  Instagram  ...                 5             5
# 2       Engineer        Rural   Facebook  ...                 6             4
# 3  Waiting staff        Rural    YouTube  ...                 3             7
# 4        Manager        Urban     TikTok  ...                 8             2
#
#       Watch Reason  DeviceType       OS  Watch Time  Self Control  \
# ...

# %%
df.columns
# Out:
# Index(['UserID', 'Age', 'Gender', 'Location', 'Income', 'Debt',
#        'Owns Property', 'Profession', 'Demographics', 'Platform',
#        'Total Time Spent', 'Number of Sessions', 'Video ID', 'Video Category',
#        'Video Length', 'Engagement', 'Importance Score', 'Time Spent On Video',
#        'Number of Videos Watched', 'Scroll Rate', 'Frequency',
#        'ProductivityLoss', 'Satisfaction', 'Watch Reason', 'DeviceType', 'OS',
#        'Watch Time', 'Self Control', 'Addiction Level', 'CurrentActivity',
#        'ConnectionType'],
#       dtype='object')

# %% [markdown]
# ### 2. Mengidentifikasi Variabel Acak
#
# Misalnya, kita mengidentifikasi kolom `Age`, `Location`, dan `Platform` sebagai variabel acak yang akan dianalisis.

# %%
print("Statistika Deskriptif untuk Variable Umur")
print(df["Age"].describe())
# Out:
# Statistika Deskriptif untuk Variable Umur
# count    1000.000000
# mean       40.986000
# std        13.497852
# min        18.000000
# 25%        29.000000
# 50%        42.000000
# 75%        52.000000
# max        64.000000
# Name: Age, dtype: float64

# %%
print("Statistika Deskriptif untuk Variable Penghasilan")
print(df["Income"].describe())
# Out:
# Statistika Deskriptif untuk Variable Penghasilan
# count     1000.000000
# mean     59524.213000
# std      23736.212925
# min      20138.000000
# 25%      38675.250000
# 50%      58805.000000
# 75%      79792.250000
# max      99676.000000
# Name: Income, dtype: float64

# %%
print("Statistika Deskriptif untuk Variable Lokasi")
print(df["Location"].describe())
# Out:
# Statistika Deskriptif untuk Variable Lokasi
# count      1000
# unique       10
# top       India
# freq        228
# Name: Location, dtype: object

# %%
print("Statistika Deskriptif untuk Variable Platform yang digunakan")
print(df["Platform"].describe())
# Out:
# Statistika Deskriptif untuk Variable Platform yang digunakan
# count       1000
# unique         4
# top       TikTok
# freq         273
# Name: Platform, dtype: object

# %% [markdown]
# ### 3. Distribusi Probabilitas untuk Variabel Numerik
#
# Menghitung dan memvisualisasikan distribusi untuk variabel `Age` sebagai variabel acak kontinu

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Distribusi Usia
sns.histplot(df['Age'], bins=20, kde=True, color='skyblue')
plt.title("Distribusi Usia Pengguna")
plt.xlabel("Usia")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# ### 4. Uji Distribusi
#
# Untuk mengetahui jenis distribusi data, kita bisa melakukan dua cara
# 1. **Analisis visual**
#    * Analisis visual bisa menggunakan histogram dan Q-Q plot
#    * Jika Q-Q plot menunjukkan bahwa data mengikuti garis lurus, itu bisa menjadi indikasi bahwa data mengikuti distribusi tertentu
# 3. **Uji statistik**
#    *
#    * Hasil dari uji statistik (seperti p-value) akan membantu kita menentukan apakah data cukup kuat untuk menolak hipotesis bahwa data berasal dari distribusi tertentu

# %%
import scipy.stats as stats

# %%
# Membuat Q-Q Plot
plt.figure(figsize=(8, 6))
stats.probplot(df['Age'], dist="norm", plot=plt)
plt.title('Q-Q Plot untuk Memeriksa Normalitas')
plt.xlabel('Teoretis Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid()
plt.show()

# %% [markdown]
# Hasil: **Tidak normal**

# %%
# Membuat Q-Q Plot
plt.figure(figsize=(8, 6))
stats.probplot(df['Age'], dist="uniform", plot=plt)
plt.title('Q-Q Plot untuk Memeriksa Distribusi Uniform')
plt.xlabel('Teoretis Quantiles')
plt.ylabel('Sample Quantiles')
plt.grid()
plt.show()

# %% [markdown]
# Hasil: **Uniform**

# %% [markdown]
# ### 6. Distribusi Probabilitas untuk Variabel Kategoris
#
# Memvisualisasikan distribusi untuk variabel kategoris `Location` dan `Platform`

# %%
# Menghitung distribusi platform yang digunakan
platform_counts_normalized = df['Platform'].value_counts(normalize=True)
platform_counts = df['Platform'].value_counts()

print("\nDistribusi Probabilitas Platform yang digunakan")
print(platform_counts)

print("\nDistribusi Probabilitas Platform yang digunakan (Normalized)")
print(platform_counts_normalized)
# Out:
# Distribusi Probabilitas Platform yang digunakan
# Platform
# TikTok       273
# Instagram    256
# YouTube      250
# Facebook     221
# Name: count, dtype: int64
#
# Distribusi Probabilitas Platform yang digunakan (Normalized)
# Platform
# TikTok       0.273
# Instagram    0.256
# YouTube      0.250
# Facebook     0.221
# Name: proportion, dtype: float64

# %% [markdown]
# Mengembalikan frekuensi relatif dari setiap nilai

# %%
# Visualisasi Distribusi Tingkat Kepuasan
sns.countplot(data=df, x='Platform')
plt.title("Distribusi Platform yang digunakan")
plt.xlabel("Platform")
plt.ylabel("Frekuensi")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd

# Contoh data: Ganti dengan data Anda
data = np.random.normal(loc=0, scale=1, size=1000)

# 1. Visualisasi Data
# Histogram
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')
plt.title('Histogram')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')
plt.show()

# Q-Q Plot
stats.probplot(data, dist="norm", plot=plt)
plt.title('Q-Q Plot')
plt.show()

# 2. Statistik Deskriptif
df = pd.DataFrame(data, columns=['Data'])
print(df.describe())

# 3. Uji Kesesuaian Distribusi


# Uji Shapiro-Wilk
shapiro_statistic, p_value_sw = stats.shapiro(data)
print(f"Shapiro-Wilk Statistic: {shapiro_statistic}, P-Value: {p_value_sw}")
# Out:
#               Data
# count  1000.000000
# mean      0.000064
# std       1.009667
# min      -3.195624
# 25%      -0.708495
# 50%       0.036929
# 75%       0.691345
# max       3.300972
# KS Statistic: 0.023748603412859226, P-Value: 0.616746758219168
# Shapiro-Wilk Statistic: 0.9985673075793821, P-Value: 0.5991216658489246
